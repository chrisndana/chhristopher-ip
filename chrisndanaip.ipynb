# %% [markdown]
# # CRISP-DM Process from Business Understanding to Data cleaning and analysis of data

# %% [markdown]
# 1) BUSINESS UNDERSTANDING
# The main goal is to establish how will the changes in price affect the quantities demanded in diffrent countries ,that is,if the price increases ,how will the demand of diffrent countries respond to that change
#
# DATA MINING GOALS
# The aim of data mining in my project is to help me predict and forecast  the quantity of stock  the customers will buy at a given price

# %% [markdown]
# 2) DATA UNDERSTANDING
# This stage enebles me as a data scientist to explore my data and see if its complete.
# I will check the type of the data if its  an excel file or csv or text file
# Also i will  scheme through my data to all columns are presented in the right manner
#   A) VERIFYING DATA QUALITY
#      After going through the data ,i will verify the data if ts completye or not
#      I will look if rthe data has any error
# i will verify the data as clean when i see that the data has no errors or missing columns

# %%
#  DATA CLEANING
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# loading the file from desktop and creating a dataftame
stockdata=pd.read_csv("archive(1).zip",encoding='latin1')
df=pd.DataFrame(stockdata)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# finding the sum of all null values in the data
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# dropping all the null values 
df1=df.dropna()
df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# findimg the shape to see if the null values have been dropped
df1.shape
# Out:
# (406829, 8)

# %%
# finding duplicates within my data and dropping them 
df1.duplicated().sum()
df2=df1.drop_duplicates()
df2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# finding the shape of the new data that  does not contain duplicatws or null  values 
df2.shape
# Out:
# (401604, 8)

# %%
# dropping the CUSTOMERID from the data since i dont require it
df3=df2.drop(columns='CustomerID')
df3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice         Country
# ...

# %%
df4=df3.describe()
df4
# Out:
#             Quantity      UnitPrice
# count  401604.000000  401604.000000
# mean       12.183273       3.474064
# std       250.283037      69.764035
# min    -80995.000000       0.000000
# 25%         2.000000       1.250000
# 50%         5.000000       1.950000
# 75%        12.000000       3.750000
# max     80995.000000   38970.000000

# %%
# data analysis using boxplot
# below is a boxplot of quantity of stock 
plt.boxplot(df2.UnitPrice)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x693951fc08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x693952de48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x693950ff88>],
#  'medians': [<matplotlib.lines.Line2D at 0x6939533ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x6939533f48>],
#  'means': []}

# %%
# finding the mean of  column UnitPrice
df3.UnitPrice.mean()
# Out:
# 3.47406363979831

# %%
# finding the standard deviation of UnitPrice
df3.UnitPrice.std()
# Out:
# 69.76403506412308

# %%
# finding the upper limit that will help me in dropping outliers 
upper_limit=df3.UnitPrice.mean()+3*df3.UnitPrice.std()
upper_limit
# Out:
# 212.76616883216755

# %%
# finding the lower limit 
lower_limit=df3.UnitPrice.mean()-3*df3.UnitPrice.std()
lower_limit
# Out:
# -205.81804155257092

# %%
df3[(df3.UnitPrice>upper_limit)| (df3.UnitPrice<lower_limit)]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 4989      536835     22655  VINTAGE RED KITCHEN CABINET         1
# 14498    C537597         D                     Discount        -1
# 19392    C537857         D                     Discount        -1
# 32484     539080     22655  VINTAGE RED KITCHEN CABINET         1
# 36165    C539438     22655  VINTAGE RED KITCHEN CABINET        -1
# ...          ...       ...                          ...       ...
# 526015    580645         M                       Manual         1
# 528082    580727       DOT               DOTCOM POSTAGE         1
# 528087   C580726      CRUK              CRUK Commission        -1
# 535003    581179      POST                      POSTAGE         1
# 541541   C581499         M                       Manual        -1
#
#              InvoiceDate  UnitPrice         Country
# 4989     12/2/2010 18:06     295.00  United Kingdom
# 14498    12/7/2010 12:34     281.00  United Kingdom
# ...

# %%
# removing the outliers compeletly
df3[(df3.UnitPrice<upper_limit)&(df3.UnitPrice>lower_limit)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice         Country
# ...

# %%
# plotting a scatter plot
plt.style.use('seaborn')
plt.scatter( df3.Country ,df3.UnitPrice)

# %% [markdown]
# # 4 ANALYSIS

# %%
# analysis of my data that is clean
df3.skew()
# Out:
# Quantity       0.179957
# UnitPrice    449.316245
# dtype: float64

# %%
#  finding kurtosis
df3.kurt()
# Out:
# Quantity      93140.274032
# UnitPrice    243760.949868
# dtype: float64

# %% [markdown]
# # 5 FORMULATING QUESTIONS
